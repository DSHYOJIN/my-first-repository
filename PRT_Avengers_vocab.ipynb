# %% [markdown]
# <a href="https://colab.research.google.com/github/peony1217-ctrl/my-first-repository/blob/master/PRT_Avengers_vocab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AIFFEL Campus Online Code Peer Review Templete
# - 코더 : 김효진
# - 리뷰어 : 이기화
#
# # PRT(Peer Review Template)
# - [⏺️]  **1. 주어진 문제를 해결하는 완성된 코드가 제출되었나요?**
#     - 문제에서 요구하는 최종 결과물이 첨부되었는지 확인
#         - 중요! 해당 조건을 만족하는 부분을 캡쳐해 근거로 첨부
#
#   ➡️ 네 주어진 Avengers 텍스트 파일을 기반으로 vocabulary를 생성하고, 문장을 정수 인덱스로 인코딩하는 최종 결과물이 제출되었음
#
#   [(https://![화면 캡처 2025-09-23 124942.png](data:image/png;base64,...))
#
#
# - [🔼]  **2. 전체 코드에서 가장 핵심적이거나 가장 복잡하고 이해하기 어려운 부분에 작성된 주석 또는 doc string을 보고 해당 코드가 잘 이해되었나요?**
#     - 해당 코드 블럭을 왜 핵심적이라고 생각하는지 확인
#     - 해당 코드 블럭에 doc string/annotation이 달려 있는지 확인
#     - 해당 코드의 기능, 존재 이유, 작동 원리 등을 기술했는지 확인
#     - 주석을 보고 코드 이해가 잘 되었는지 확인
#         - 중요! 잘 작성되었다고 생각되는 부분을 캡쳐해 근거로 첨부
#
#    ➡️ 제가 생각하는 코드의 핵심은 함수와 class를 엮어 재사용 가능하게 만든 구조임. Vocab 클래스를 통해 텍스트 전처리, 단어 빈도 계산, 정렬, 단어-정수 매핑이 모두 묶여 있으며, encode 메서드에서 문장을 정수로 변환하도록 구현했음.
#    다만, 코드 내 주석이 부족해서 동작을 이해하는 데 시간이 조금 걸렸음
#    ![image.png](data:image/png;base64,...)
#
# - [⏺️]  **3. 에러가 난 부분을 디버깅하여 문제를 해결한 기록을 남겼거나
# 새로운 시도 또는 추가 실험을 수행해봤나요?**
#     - 문제 원인 및 해결 과정을 잘 기록하였는지 확인
#     - 프로젝트 평가 기준에 더해 추가적으로 수행한 나만의 시도,
#     실험이 기록되어 있는지 확인
#         - 중요! 잘 작성되었다고 생각되는 부분을 캡쳐해 근거로 첨부
#
#    ➡️실행 시 큰 에러는 없었지만, 결과가 [2, 120, 3, 536]으로 원했던 결과값인 [2, 121, 3, 541]과 달랐음. 이유를 확인해보니 정렬 기준을 단순히 (-count, word)로 두었기 때문에 발생한 차이여서 정렬 기준을 다르게 하는 코드로 수정한다면, 원하는 결과값을 받을 수 있을 것 같음
#
# - [❌]  **4. 회고를 잘 작성했나요?**
#     - 주어진 문제를 해결하는 완성된 코드 내지 프로젝트 결과물에 대해
#     배운점과 아쉬운점, 느낀점 등이 기록되어 있는지 확인
#     - 전체 코드 실행 플로우를 그래프로 그려서 이해를 돕고 있는지 확인
#         - 중요! 잘 작성되었다고 생각되는 부분을 캡쳐해 근거로 첨부
#
#    ➡️ 회고 작성은 없었습니다.
#
# - [⏺️]  **5. 코드가 간결하고 효율적인가요?**
#     - 파이썬 스타일 가이드 (PEP8) 를 준수하였는지 확인
#     - 코드 중복을 최소화하고 범용적으로 사용할 수 있도록 함수화/모듈화했는지 확인
#         - 중요! 잘 작성되었다고 생각되는 부분을 캡쳐해 근거로 첨부
#
#    ➡️ Counter와 sorted를 활용해 불필요한 반복문 없이 핵심 로직을 구혔했고, 코드가 함수화 및 class화 되어 있어 확장성이 좋았음.
#
# 회고 (리뷰어: 이기화)
#
# 이번 코드를 리뷰하면서, class를 사용해 함수와 기능을 잘 묶어낸 구조가 특히 인상적이었습니다. 저는 함수 정의부와 사용 예시부를 분리하는 방식을 강조해서 사용했는데, 이 코드는 아예 class로 기능을 사용하여 재사용성을 높였습니다.
# 다만 단어 인덱싱이 기대한 값과 달랐던 이유가 정렬 기준 처리 문제였다는 점도 확인할 수 있었고, 이런 세부 구현에서 결과 차이가 생길 수 있다는 걸 다시 배웠습니다.
# 앞으로는 저도 class와 함수 구조를 적절히 병행해서, 더 범용적이고 일관된 코드를 작성해야겠다고 느꼈습니다.
